# %% [markdown]
# <a href="https://colab.research.google.com/github/BiancaPedrosa/datascience/blob/master/Bootcamp1_Tuberculose.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Projeto Módulo I Bootcamp Alura
# Bianca Pedrosa
# Análise dos casos de turbeculose no estado de SP entre 2009 - 2018

# %% [markdown]
# Importação de bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %% [markdown]
# Leitura dos dados

# %%
#tabela completa

url="https://raw.githubusercontent.com/BiancaPedrosa/datascience/master/dados/tabelautf8a.csv"

dados = pd.read_csv(url, encoding="ISO-8859-1", engine='python', sep=";",thousands=".", decimal=",", skiprows=1,index_col=0)
dados
# Out:
#                          ID   2009   POP2009  ...   2018   POP2018     TOTAL
# MUNICIPIO                                     ...
# ADAMANTINA        3500105.0      5   34424.0  ...      5   35023.0      51.0
# ADOLFO            3500204.0      -    3710.0  ...      -    3571.0       9.0
# AGUAI             3500303.0      8   32101.0  ...      3   35954.0      93.0
# AGUAS DA PRATA    3500402.0      -    7734.0  ...      1    8137.0       4.0
# AGUAS DE LINDOIA  3500501.0      2   16341.0  ...      2   18599.0      26.0
# ...                     ...    ...       ...  ...    ...       ...       ...
# VITORIA BRASIL    3556958.0      -    1662.0  ...      -    1834.0       5.0
# VOTORANTIM        3557006.0     42  105193.0  ...     47  121331.0     386.0
# VOTUPORANGA       3557105.0     20   81279.0  ...     19   93736.0     186.0
# ZACARIAS          3557154.0      1    2427.0  ...      -    2684.0       3.0
# TOTAL                   NaN  17807       NaN  ...  22225       NaN  197354.0
#
# [646 rows x 22 columns]

# %% [markdown]
# Tratando a ausência de dados

# %%
dados = dados.replace('-', np.nan)
dados.head()
# Out:
#                          ID 2009  POP2009 2010  ...  POP2017 2018  POP2018 TOTAL
# MUNICIPIO                                       ...
# ADAMANTINA        3500105.0    5  34424.0    5  ...  35139.0    5  35023.0  51.0
# ADOLFO            3500204.0  NaN   3710.0  NaN  ...   3609.0  NaN   3571.0   9.0
# AGUAI             3500303.0    8  32101.0   14  ...  35508.0    3  35954.0  93.0
# AGUAS DA PRATA    3500402.0  NaN   7734.0  NaN  ...   8104.0    1   8137.0   4.0
# AGUAS DE LINDOIA  3500501.0    2  16341.0    3  ...  18509.0    2  18599.0  26.0
#
# [5 rows x 22 columns]

# %% [markdown]
# Conferindo as células sem valor

# %%
dados.T.info()
dados.isnull().sum().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, ID to TOTAL
# Columns: 646 entries, ADAMANTINA to TOTAL
# dtypes: object(646)
# memory usage: 111.8+ KB
# 1526

# %%
dados = dados.astype('float64')
dados.head()
# Out:
#                          ID  2009  POP2009  2010  ...  POP2017  2018  POP2018  TOTAL
# MUNICIPIO                                         ...
# ADAMANTINA        3500105.0   5.0  34424.0   5.0  ...  35139.0   5.0  35023.0   51.0
# ADOLFO            3500204.0   NaN   3710.0   NaN  ...   3609.0   NaN   3571.0    9.0
# AGUAI             3500303.0   8.0  32101.0  14.0  ...  35508.0   3.0  35954.0   93.0
# AGUAS DA PRATA    3500402.0   NaN   7734.0   NaN  ...   8104.0   1.0   8137.0    4.0
# AGUAS DE LINDOIA  3500501.0   2.0  16341.0   3.0  ...  18509.0   2.0  18599.0   26.0
#
# [5 rows x 22 columns]

# %% [markdown]
# Selecionando as colunas usáveis

# %%
dados_usaveis = dados.loc[:,'2009':'2018']
dados_usaveis
# Out:
#                      2009   POP2009     2010  ...     2017   POP2017     2018
# MUNICIPIO                                     ...
# ADAMANTINA            5.0   34424.0      5.0  ...      5.0   35139.0      5.0
# ADOLFO                NaN    3710.0      NaN  ...      2.0    3609.0      NaN
# AGUAI                 8.0   32101.0     14.0  ...      7.0   35508.0      3.0
# AGUAS DA PRATA        NaN    7734.0      NaN  ...      1.0    8104.0      1.0
# AGUAS DE LINDOIA      2.0   16341.0      3.0  ...      5.0   18509.0      2.0
# ...                   ...       ...      ...  ...      ...       ...      ...
# VITORIA BRASIL        NaN    1662.0      1.0  ...      NaN    1833.0      NaN
# VOTORANTIM           42.0  105193.0     38.0  ...     38.0  119898.0     47.0
# VOTUPORANGA          20.0   81279.0     29.0  ...     10.0   92768.0     19.0
# ZACARIAS              1.0    2427.0      NaN  ...      2.0    2636.0      NaN
# TOTAL             17807.0       NaN  18178.0  ...  22019.0       NaN  22225.0
#
# [646 rows x 19 columns]

# %%
dados["new2009"] = np.where(dados["2009"]==np.nan,  np.nan,(dados["2009"]/dados["POP2009"]))
dados["new2010"] = np.where(dados["2010"]==np.nan,  np.nan,(dados["2010"]/dados["POP2010"]))
dados["new2011"] = np.where(dados["2011"]==np.nan,  np.nan,(dados["2011"]/dados["POP2011"]))
dados["new2012"] = np.where(dados["2012"]==np.nan,  np.nan,(dados["2012"]/dados["POP2012"]))
dados["new2013"] = np.where(dados["2013"]==np.nan,  np.nan,(dados["2013"]/dados["POP2013"]))
dados["new2014"] = np.where(dados["2014"]==np.nan,  np.nan,(dados["2014"]/dados["POP2014"]))
dados["new2015"] = np.where(dados["2015"]==np.nan,  np.nan,(dados["2015"]/dados["POP2015"]))
dados["new2016"] = np.where(dados["2016"]==np.nan,  np.nan,(dados["2016"]/dados["POP2016"]))
dados["new2017"] = np.where(dados["2017"]==np.nan,  np.nan,(dados["2017"]/dados["POP2017"]))
dados["new2018"] = np.where(dados["2018"]==np.nan,  np.nan,(dados["2018"]/dados["POP2018"]))
dadospop = dados.loc[:,"new2009":"new2018"]
dadospop
# Out:
#                    new2009   new2010   new2011  ...   new2016   new2017   new2018
# MUNICIPIO                                       ...
# ADAMANTINA        0.000145  0.000148  0.000148  ...  0.000114  0.000142  0.000143
# ADOLFO                 NaN       NaN  0.000282  ...  0.000553  0.000554       NaN
# AGUAI             0.000249  0.000435  0.000370  ...  0.000284  0.000197  0.000083
# AGUAS DA PRATA         NaN       NaN       NaN  ...       NaN  0.000123  0.000123
# AGUAS DE LINDOIA  0.000122  0.000174  0.000058  ...  0.000272  0.000270  0.000108
# ...                    ...       ...       ...  ...       ...       ...       ...
# VITORIA BRASIL         NaN  0.000576  0.001148  ...  0.000547       NaN       NaN
# VOTORANTIM        0.000399  0.000349  0.000337  ...  0.000353  0.000317  0.000387
# VOTUPORANGA       0.000246  0.000342  0.000234  ...  0.000217  0.000108  0.000203
# ZACARIAS          0.000412       NaN       NaN  ...       NaN  0.000759       NaN
# TOTAL                  NaN       NaN       NaN  ...       NaN       NaN       NaN
#
# [646 rows x 10 columns]

# %%
#ordenando
dadospop["Total"] = dadospop.sum(axis=1)
ordenado = dadospop.sort_values("Total", ascending=False)
ordenado = ordenado.drop(columns=['Total'])
ordenado.head(10)
# Out:
#                        new2009   new2010  ...   new2017   new2018
# MUNICIPIO                                 ...
# BALBINOS              0.006813  0.005341  ...  0.014264  0.010484
# LAVINIA               0.005506  0.007060  ...  0.012370  0.008143
# SUZANO                0.000348  0.000339  ...  0.031022  0.031961
# ALVARO DE CARVALHO    0.004213  0.005161  ...  0.006642  0.006179
# MARABA PAULISTA       0.002835  0.003117  ...  0.005881  0.005211
# PRACINHA              0.002446  0.004191  ...  0.004246  0.004281
# PACAEMBU              0.002613  0.002938  ...  0.007951  0.006440
# IRAPURU               0.001651  0.002055  ...  0.004001  0.004721
# POTIM                 0.002951  0.003863  ...  0.003938  0.002444
# PRESIDENTE BERNARDES  0.000325  0.000222  ...  0.006632  0.003639
#
# [10 rows x 10 columns]

# %%
grafico = ordenado.head(10).T.plot(figsize=(12, 6))
plt.title('Top 10 Casos de tuberculose no estado de SP', fontsize = 20, fontweight = 'bold')

grafico.set_xlabel('Ano', fontsize=12,fontweight = 'bold')
grafico.set_ylabel('Nº de Internação', fontsize=12, fontweight = 'bold')
# Out:
# Text(0, 0.5, 'Nº de Internação')
