# %% [markdown]
# <a href="https://colab.research.google.com/github/BiancaPedrosa/datascience/blob/master/Bootcamp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Projeto Módulo I Bootcamp Alura
# Bianca Pedrosa
# Análise dos casos de turbeculose no estado de SP entre 2009 - 2018

# %% [markdown]
# Importação de bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Leitura dos dados

# %%
#tabela completa
url="/content/A172345189_28_143_208.csv"


dados = pd.read_csv(url, encoding="ISO-8859-1", engine='python',skiprows=3, skipfooter=18, sep=";",thousands=".", decimal=",", index_col=0).drop('Total', axis=1)
dados
# Out:
#                               1980 1981 1983 1984  ...   2017   2018 2019 2020
# Município de notificação                           ...
# 350010 Adamantina                -    -    -    -  ...      5      4    -    -
# 350020 Adolfo                    -    -    -    -  ...      1      -    -    -
# 350030 Aguaí                     -    -    -    -  ...      7      3    -    -
# 350050 Águas de Lindóia          -    -    -    -  ...      5      2    -    -
# 350055 Águas de Santa Bárbara    -    -    -    -  ...      -      2    -    -
# ...                            ...  ...  ...  ...  ...    ...    ...  ...  ...
# 355695 Vitória Brasil            -    -    -    -  ...      -      -    -    -
# 355700 Votorantim                -    -    -    -  ...     36     45    -    -
# 355710 Votuporanga               -    -    -    -  ...     19     24    -    -
# 355715 Zacarias                  -    -    -    -  ...      1      -    -    -
# ...

# %% [markdown]
# Tratando a ausência de dados

# %%
dados = dados.replace('-', np.nan)
dados.head()
# Out:
#                               1980 1981 1983 1984 1985  ... 2016 2017 2018 2019 2020
# Município de notificação                                ...
# 350010 Adamantina              NaN  NaN  NaN  NaN  NaN  ...    3    5    4  NaN  NaN
# 350020 Adolfo                  NaN  NaN  NaN  NaN  NaN  ...    1    1  NaN  NaN  NaN
# 350030 Aguaí                   NaN  NaN  NaN  NaN  NaN  ...    9    7    3  NaN  NaN
# 350050 Águas de Lindóia        NaN  NaN  NaN  NaN  NaN  ...    3    5    2  NaN  NaN
# 350055 Águas de Santa Bárbara  NaN  NaN  NaN  NaN  NaN  ...    1  NaN    2  NaN  NaN
#
# [5 rows x 37 columns]

# %% [markdown]
# Conferindo as células sem valor

# %%
dados.T.info()
dados.isnull().sum().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, 1980 to 2020
# Columns: 621 entries, 350010 Adamantina to Total
# dtypes: object(621)
# memory usage: 181.0+ KB
# 18351

# %%
dados = dados.astype('float64')
dados.head()
# Out:
#                                1980  1981  1983  1984  ...  2017  2018  2019  2020
# Município de notificação                               ...
# 350010 Adamantina               NaN   NaN   NaN   NaN  ...   5.0   4.0   NaN   NaN
# 350020 Adolfo                   NaN   NaN   NaN   NaN  ...   1.0   NaN   NaN   NaN
# 350030 Aguaí                    NaN   NaN   NaN   NaN  ...   7.0   3.0   NaN   NaN
# 350050 Águas de Lindóia         NaN   NaN   NaN   NaN  ...   5.0   2.0   NaN   NaN
# 350055 Águas de Santa Bárbara   NaN   NaN   NaN   NaN  ...   NaN   2.0   NaN   NaN
#
# [5 rows x 37 columns]

# %%
#Plotando os dados de Campinas
dados_campinas= dados.loc['350950 Campinas', '2009':'2018']
dados_campinas.plot(figsize=(10, 6),marker='o')
